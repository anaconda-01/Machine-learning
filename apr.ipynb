# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv("Apriori _ Market_Basket_Optimisation.csv",header=None)
df.head()
# Out:
#               0          1           2                 3             4   \
# 0         shrimp        nut       lemon    vegetables mix  green grapes
# 1        burgers  meatballs        eggs               NaN           NaN
# 2        chutney        NaN         NaN               NaN           NaN
# 3         turkey      lemon         NaN               NaN           NaN
# 4  mineral water       milk  energy bar  whole wheat rice      iced tea
#
#                  5     6               7             8             9   \
# 0  whole weat flour  yams  cottage cheese  energy drink  tomato juice
# 1               NaN   NaN             NaN           NaN           NaN
# 2               NaN   NaN             NaN           NaN           NaN
# 3               NaN   NaN             NaN           NaN           NaN
# 4               NaN   NaN             NaN           NaN           NaN
#
#                10        11     12     13             14      15  \
# ...

# %%
df.shape
list1=[]

# %%
for i in range(0,7501):
    for j in range(0,20):
        list1.append(df.values[i,j])

# %%
from apyori import apriori
rules=apriori(list1,min_support=0.03,min_confidence=0.2,min_lift=3,min_length=2)

# %%
resutls=list(rules)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# d:\MyCode\python\apr.ipynb Cell 7 line 1
# ----> <a href='vscode-notebook-cell:/d%3A/MyCode/python/apr.ipynb#X11sZmlsZQ%3D%3D?line=0'>1</a> resutls=list(rules)
#
# TypeError: 'list' object is not callable
